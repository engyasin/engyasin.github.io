# %% [markdown]
# # هندسة الميكاترونيك
#
# هي اختصاصي الاصلي , أعمل حالياً في جامعة البعث (سورية)  كمحاضر , وادرس لاطروحة الماجستير في نفس الاختصاص , للعام الدراسي الحالي
#
#
# مجالات دراستي متنوعة , واركز عموماً على العلوم الهندسية , إلى جانب بعض الهوايات

# %% [markdown]
# <img src="/images/2016.jpg" />

# %% [markdown]
# > للتوسع لاحقاً...
