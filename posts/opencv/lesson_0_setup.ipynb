# %% [markdown]
# # الدرس صفر : الاعداد

# %% [markdown]
# ## تنصيب OpenCV-Python  في Windows:

# %% [markdown]
# ### الهدف :
#
# ** في هذا الفصل **
#
# * سنتعلم تنصيب OpenCV-Python  على نظام  Windows.
#
# *الخطوات أدناه تم اختبارها على نظام  Windows 7-64 bit *

# %% [markdown]
# ### تنصيب OpenCV من الملفات الثنائية مسبقة البناء :
#
# حمل OpenCV من https://www.opencv.org
#
# * حزم بايثون التالية يجب تنصيبها بعد تحميلها بالنسخ الموافقة .
#
# >> **1.1 python 2.7.x**
#
# >> **Numpy**
#
# >> **Matplotlib (اختيارية , ولكن أفضل ).**
#
# 2. نصب كل ما سبق باماكنه المحددة . وسيتم تنصيب بايثون في  **C:/Python27/.**
#
# 3. بعد التنصيب , افتح IDLE  واكتب  `import numpy ` وتأكد أن Numpy  يعمل بشكل جيد .
#
# 4. حمل آخر إصدار من OpenCV  من موقع www.sourcefroge.com  واضغط مرتين على الملف لفك ضغطه.
#
# 5. اذهب إلى مجلد **opencv/build/python/2.7 **
#
# 6. انسخ ملف **cv2.pyd**  الى **C:/Python27/lib/site-packeges.**
#
# 7. افتح IDLE  واكتب التالي عند المؤشر .

# %%
import cv2

print cv2.__version__
# Out:
# 3.1.0

# %% [markdown]
# إذا تم طباعة النتيجة بلا أخطاء , فتهانينا  !!! , لقد نصبت OpenCV-Python  بنجاح .

# %% [markdown]
# ### ملاحظة 1:
#
# لم أورد هنا البناء من المصدر , لانه يحتوي خطوات مطولة لا داعي لها هنا في هذا المنهج .
#
# على الرغم من انها توفر بعض الميزات الخاصة .

# %% [markdown]
# ### ملاحظة 2:
#
# للبدء ببرامج الحسابات العلمية , اوصي بشدة بتحميل مكتبات جاهزة ومعروفة لذلك .
#
# يمكنك تنزيل مكتبات جاهزة بكثير من الاضافات الممتازة لبايثون مسبقاً , كما في anaconda  وهي مجانية مما يوفر الوقت .

# %% [markdown]
# ## ملاحظة 3:
#
# نسخ opencv و python 3 , والتي يمكن تنصيبها عبر الأمر

# %%
pip install opencv-python

# %% [markdown]
# لن تعمل فيها , إضافات السمات SIFT , SURF  وستحتاج لبناء أكواد أخرى من المصدر , لذلك , فلا ينصح بها هنا .
#
# إذا تمكنت من تنصيب تلك الاكواد , بطريقة أو بأخرى , فمعظم التعليمات هنا يمكن تعميمها
