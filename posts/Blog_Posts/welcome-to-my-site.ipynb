# %% [markdown]
# # تقديم
#
# أهلاً بهذه الصفحات , التي تم تخصيصها لمواضيع تقنية متنوعة , وتحديداً بما يخص علوم الحاسوب والعلوم الهندسية ، ومن المواضيع التي من المحتمل جداً العمل عليها :
#
# <strong>
#
# * Python
#
# * Matlab
#
# * javascript
#
# * PHP
#
# * Prolog
#
# * ++C
#
# * Computer Networking
#
# * Signal Processing
#
# * Scientific Computing
#
# * Bitcoin Technology
#
# * Blender (3D Modelling)
#
#
# كل ذلك سيكون بالترجمة عن الانكليزية للعربية وبشكل مفهوم , وذلك لفائدة القارئ
#
# إذا وجدت المحتوى مفيداً لك , يمكنك الاستمرار بمتابعتي على صفحاتي في مواقع التواصل ، كما يمكنك وضع "نجمة" لهذه المدونة في موقع Github  [هنا](https://www.github.com/engyasin/engyasin)

# %% [markdown]
# الصفحة الرئيسية تحتوي جدولاً بالكتب الجاري العمل عليها , بالاضافة , للمنشورات العادية , كرابط بآخر الجدول..
#
# * http://engyasin.github.io/index.html
#
#
# <img src="/images/Books_may_be_translated.png" />

# %% [markdown]
# ## ما هو الجوبتر نوتبوك؟
#
# `Jupyter notebook` هي تقنية للكتابة العلمية , يمكن منها التحويل ل pdf  وأيضاً لعرض شرائح , وكذلك لمنشورات علمية بصيغة  `latex`  وبالتالي فلامكانات واسعة , وهذه المنشورات بحد ذاتها مكتوبة ضمن بيئة الجوبتر , والتي تم تنصيب العديد من اللغات فيها , حيث يتم الشرح والبرمجة فيها بآن معاً
#
# , بالنسبة للغة العربية , الدعم ضعيف , ولكن هذا قابل للتغيير مستقبلاً
# [الرابط](https://github.com/jupyter)

# %% [markdown]
# ## أبدي رأيك:
#
# ضمن المنشورات , هناك قسم للتعليقات , إذا كان لديك سؤال , أو إذا أردت طرح فكرة , فالمجال مفتوح
#
# على كلٍ , انتظر دائماً اهتماماً ما بمجال ما لاكترث لكتاب أكثر من آخر ...

# %%
print "Hello World"
# Out:
# Hello World
