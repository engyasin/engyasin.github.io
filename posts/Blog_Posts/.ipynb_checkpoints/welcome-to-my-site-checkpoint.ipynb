# %% [markdown]
# # ميمون الابتداء
#
# مرحباً , في هذه الصفحات , التي ستشمل قريباً مواضيع شتى , في لغات متعددة , منها :
#
#
# * Python
#
# * Matlab
#
# * javascript
#
# * PHP
#
# * Prolog
#
# * C++
#
#
# بالاضافة لمنشورات مفيدة , معنونة ومفهرسة , في مجالات هندسة المعلومات وغيرها ,

# %% [markdown]
# ## العمل:
#
# سأشرع بالكتابة شيئاً فشيئاً , قد أكتب عدة منشورات بيوم واحد , أو منشوراً كل عدة إسابيع , ليس هناك قيد , ولكن سأنظمها , ضمن كتب مفتوحة المصدر , وأشير إلى مراجعها , مع ملاحظة أن الترجمة قد لاتكون شاملة , ومع حرصي أن لا أنقص شيئاً كثيراً أو مهماً

# %% [markdown]
# ## ما هو الجوبتر نوتبوك:
#
# `Jupyter notebook` هي تقنية للكتابة العلمية , يمكن منها التحويل ل pdf  وأيضاً لعرض شرائح , وبل وحتى لمنشورات علمية , `latex`  وبالتالي فلامكانات واسعة , وهذه المنشورات بحد ذاتها مكتوبة ضمن بيئة الجوبتر , والتي قمت بتنصيب العديد من اللغات فيها , حيث يتم الشرح والبرمجة فيها بآن معاً
#
# , بالنسبة للغة العربية , الدعم ضعيف , وهذا بالواقع هو من إحدى أهدافي هنا , وهو تغيير ذلك
#
# [الرابط](https://github.com/jupyter)

# %% [markdown]
# ## أبدي رأيك:
#
# ضمن المنشورات , هناك قسم للتعليقات , إذا كان لديك سؤال , أو إذا أردت طرح فكرة , فالمجال مفتوح
#
# على كلٍ , لم أحدد بعد الكتب التي سأترجمها مستقبلاً , وانتظر دائماً اهتماماً ما بمجال ما لاكترث لكتاب أكثر من آخر , وهذا هو ما سيكون طرحي على القراء...

# %%
print "Hello World"
# Out:
# Hello World
